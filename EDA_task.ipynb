# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/3.Cuisine_rating.csv")
df
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 1          2        123       St. George,NY  Female  1991        Married
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 4          5        129     Central Park,NY    Male  1997         Single
# ..       ...        ...                 ...     ...   ...            ...
# 195      196        175       St. George,NY  Female  1982         Single
# 196      197        170  Upper West Side,NY  Female  2000        Married
# 197      198        160       St. George,NY  Female  2006         Single
# 198      199        130       St. George,NY    Male  2002        Married
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
#          Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %%
df.describe()
# Out:
#           User ID   Area code          YOB      Budget  Food Rating  \
# count  200.000000  200.000000   200.000000  200.000000   200.000000
# mean   100.500000  141.060000  1984.830000    3.815000     3.220000
# std     57.879185   26.130257    16.809339    1.056578     1.411226
# min      1.000000  101.000000  1955.000000    1.000000     1.000000
# 25%     50.750000  123.000000  1971.000000    3.000000     2.000000
# 50%    100.500000  135.000000  1987.000000    4.000000     3.000000
# 75%    150.250000  158.000000  2000.000000    5.000000     5.000000
# max    200.000000  199.000000  2009.000000    5.000000     5.000000
#
#        Service Rating  Overall Rating
# count      200.000000      200.000000
# mean         3.230000        3.225000
# std          1.526022        1.079445
# min          1.000000        1.000000
# 25%          2.000000        2.500000
# 50%          3.000000        3.000000
# 75%          5.000000        4.000000
# max          5.000000        5.000000

# %%
df.corr()
# Out:
# <ipython-input-4-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                  User ID  Area code       YOB    Budget  Food Rating  \
# User ID         1.000000   0.463977  0.006203 -0.010148    -0.003691
# Area code       0.463977   1.000000 -0.065006 -0.046191     0.000458
# YOB             0.006203  -0.065006  1.000000 -0.071383     0.040774
# Budget         -0.010148  -0.046191 -0.071383  1.000000     0.057764
# Food Rating    -0.003691   0.000458  0.040774  0.057764     1.000000
# Service Rating  0.111227  -0.011942  0.043651 -0.135542     0.079056
# Overall Rating  0.076208  -0.008142  0.057508 -0.058049     0.709562
#
#                 Service Rating  Overall Rating
# User ID               0.111227        0.076208
# Area code            -0.011942       -0.008142
# ...

# %%
df.columns
# Out:
# Index(['User ID', 'Area code', 'Location', 'Gender', 'YOB', 'Marital Status',
#        'Activity', 'Budget', 'Cuisines', 'Alcohol ', 'Smoker', 'Food Rating',
#        'Service Rating', 'Overall Rating', 'Often A S'],
#       dtype='object')

# %%
df.drop('User ID', axis = 1, inplace = True)

# %%
df
# Out:
#      Area code            Location  Gender   YOB Marital Status      Activity  \
# 0          153  Upper East Side,NY  Female  2006         Single  Professional
# 1          123       St. George,NY  Female  1991        Married       Student
# 2          122  Upper West Side,NY    Male  1977         Single       Student
# 3          153  Upper East Side,NY  Female  1956        Married  Professional
# 4          129     Central Park,NY    Male  1997         Single       Student
# ..         ...                 ...     ...   ...            ...           ...
# 195        175       St. George,NY  Female  1982         Single  Professional
# 196        170  Upper West Side,NY  Female  2000        Married       Student
# 197        160       St. George,NY  Female  2006         Single  Professional
# 198        130       St. George,NY    Male  2002        Married       Student
# 199        140  Upper East Side,NY    Male  2005        Married       Student
#
# ...

# %%
df.dtypes
# Out:
# Area code           int64
# Location           object
# Gender             object
# YOB                 int64
# Marital Status     object
# Activity           object
# Budget              int64
# Cuisines           object
# Alcohol            object
# Smoker             object
# Food Rating         int64
# Service Rating      int64
# Overall Rating    float64
# Often A S          object
# dtype: object

# %%
df.Gender.value_counts()
# Out:
# Male      118
# Female     82
# Name: Gender, dtype: int64

# %%
df['Marital Status'].value_counts()
# Out:
# Single      100
# Married      86
# Divorced     14
# Name: Marital Status, dtype: int64

# %%
df.Activity.value_counts()
# Out:
# Student         120
# Professional     80
# Name: Activity, dtype: int64

# %%
df.Cuisines.value_counts()
# Out:
# Japanese    36
# Filipino    34
# French      34
# Indian      32
# Chinese     24
# Seafood     22
# Italian     18
# Name: Cuisines, dtype: int64

# %%
df['Alcohol '].value_counts()
# Out:
# Never       88
# Often       61
# Socially    51
# Name: Alcohol , dtype: int64

# %%
df.Smoker.value_counts()
# Out:
# Socially    71
# Often       70
# Never       59
# Name: Smoker, dtype: int64

# %%
df.Location.value_counts()
# Out:
# St. George,NY         46
# Upper East Side,NY    30
# Riverdale,NY          28
# Central Park,NY       24
# China Town, NY        22
# Market City, NY       20
# Upper West Side,NY    18
# Central Park,ny        8
# Market City, MY        2
# Cedar Hill, NY         2
# Name: Location, dtype: int64

# %%
df['Often A S'].value_counts()
# Out:
# No     174
# Yes     26
# Name: Often A S, dtype: int64

# %%
df.drop('Often A S', axis = 1, inplace = True)

# %%
df
# Out:
#      Area code            Location  Gender   YOB Marital Status      Activity  \
# 0          153  Upper East Side,NY  Female  2006         Single  Professional
# 1          123       St. George,NY  Female  1991        Married       Student
# 2          122  Upper West Side,NY    Male  1977         Single       Student
# 3          153  Upper East Side,NY  Female  1956        Married  Professional
# 4          129     Central Park,NY    Male  1997         Single       Student
# ..         ...                 ...     ...   ...            ...           ...
# 195        175       St. George,NY  Female  1982         Single  Professional
# 196        170  Upper West Side,NY  Female  2000        Married       Student
# 197        160       St. George,NY  Female  2006         Single  Professional
# 198        130       St. George,NY    Male  2002        Married       Student
# 199        140  Upper East Side,NY    Male  2005        Married       Student
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

def encode_df(dataframe):
    le = LabelEncoder()
    for column in dataframe.columns:
        dataframe[column] = le.fit_transform(dataframe[column])
    return dataframe

encode_df(df)
# Out:
#      Area code  Location  Gender  YOB  Marital Status  Activity  Budget  \
# 0           33         8       0   43               2         0       2
# 1           14         7       0   30               1         1       2
# 2           13         9       1   17               2         1       4
# 3           33         8       0    1               1         0       4
# 4           18         1       1   34               2         1       3
# ..         ...       ...     ...  ...             ...       ...     ...
# 195         48         7       0   22               2         0       3
# 196         45         9       0   37               1         1       3
# 197         38         7       0   43               2         0       4
# 198         19         7       1   39               1         1       2
# 199         27         8       1   42               1         1       3
#
#      Cuisines  Alcohol   Smoker  Food Rating  Service Rating  Overall Rating
# ...

# %%
df.corr()
# Out:
#                 Area code  Location    Gender       YOB  Marital Status  \
# Area code        1.000000 -0.000544  0.011161 -0.066946       -0.126050
# Location        -0.000544  1.000000 -0.216659 -0.028620       -0.143505
# Gender           0.011161 -0.216659  1.000000 -0.124711        0.020641
# YOB             -0.066946 -0.028620 -0.124711  1.000000        0.450594
# Marital Status  -0.126050 -0.143505  0.020641  0.450594        1.000000
# Activity         0.001110 -0.118050  0.149410  0.259236        0.105259
# Budget          -0.047057  0.221735 -0.117390 -0.064563        0.198079
# Cuisines         0.016338 -0.087561  0.119196  0.057098       -0.009439
# Alcohol         -0.008978 -0.111500  0.097924 -0.038778        0.018932
# Smoker          -0.019247  0.055018 -0.114812 -0.157008       -0.031668
# Food Rating     -0.005610 -0.011548 -0.064707  0.046763        0.029076
# Service Rating  -0.012010 -0.169914 -0.061042  0.034888       -0.094111
# ...

# %%
plt.title("Relation between Alcohol and Food Rating")
sns.countplot(df, x = "Alcohol ", hue = "Food Rating")
# Out:
# <Axes: title={'center': 'Relation between Alcohol and Food Rating'}, xlabel='Alcohol ', ylabel='count'>

# %%
plt.title("Relation between Location and Budget")
sns.countplot(df, x = "Location", hue = "Budget")
# Out:
# <Axes: title={'center': 'Relation between Location and Budget'}, xlabel='Location', ylabel='count'>

# %%
plt.title("Relation between Location and Marital Status")
sns.countplot(df, x = "Location", hue = "Marital Status")
# Out:
# <Axes: title={'center': 'Relation between Location and Marital Status'}, xlabel='Location', ylabel='count'>

# %%
plt.title("Relation between Budget and Marital Status")
sns.countplot(df, x = "Budget", hue = "Marital Status")
# Out:
# <Axes: title={'center': 'Relation between Budget and Marital Status'}, xlabel='Budget', ylabel='count'>

# %%
df.corr()
# Out:
#                 Area code  Location    Gender       YOB  Marital Status  \
# Area code        1.000000 -0.000544  0.011161 -0.066946       -0.126050
# Location        -0.000544  1.000000 -0.216659 -0.028620       -0.143505
# Gender           0.011161 -0.216659  1.000000 -0.124711        0.020641
# YOB             -0.066946 -0.028620 -0.124711  1.000000        0.450594
# Marital Status  -0.126050 -0.143505  0.020641  0.450594        1.000000
# Activity         0.001110 -0.118050  0.149410  0.259236        0.105259
# Budget          -0.047057  0.221735 -0.117390 -0.064563        0.198079
# Cuisines         0.016338 -0.087561  0.119196  0.057098       -0.009439
# Alcohol         -0.008978 -0.111500  0.097924 -0.038778        0.018932
# Smoker          -0.019247  0.055018 -0.114812 -0.157008       -0.031668
# Food Rating     -0.005610 -0.011548 -0.064707  0.046763        0.029076
# Service Rating  -0.012010 -0.169914 -0.061042  0.034888       -0.094111
# ...

# %%
plt.title("Relation between YOB and Marital Status")
sns.countplot(df, x = "YOB", hue = "Marital Status")
# Out:
# <Axes: title={'center': 'Relation between YOB and Marital Status'}, xlabel='YOB', ylabel='count'>

# %%
plt.title("Relation between YOB and Overall Rating")
sns.countplot(df, x = "YOB", hue = "Overall Rating")
# Out:
# <Axes: title={'center': 'Relation between YOB and Overall Rating'}, xlabel='YOB', ylabel='count'>

# %%
plt.title("Relation between Marital Status and Overall Rating")
sns.countplot(df, x = "Marital Status", hue = "Overall Rating")
# Out:
# <Axes: title={'center': 'Relation between Marital Status and Overall Rating'}, xlabel='Marital Status', ylabel='count'>

# %%
plt.title("Relation between Activity and Overall Rating")
sns.countplot(df, x = "Activity", hue = "Overall Rating")
# Out:
# <Axes: title={'center': 'Relation between Activity and Overall Rating'}, xlabel='Activity', ylabel='count'>

# %%
plt.title("Relation between Budget and Overall Rating")
sns.countplot(df, x = "Budget", hue = "Overall Rating")
# Out:
# <Axes: title={'center': 'Relation between Budget and Overall Rating'}, xlabel='Budget', ylabel='count'>

# %%
plt.title("Relation between Cuisines and Overall Rating")
sns.countplot(df, x = "Cuisines", hue = "Overall Rating")
# Out:
# <Axes: title={'center': 'Relation between Cuisines and Overall Rating'}, xlabel='Cuisines', ylabel='count'>

# %%
plt.title("Relation between Alcohol and Overall Rating")
sns.countplot(df, x = "Alcohol ", hue = "Overall Rating")
# Out:
# <Axes: title={'center': 'Relation between Alcohol and Overall Rating'}, xlabel='Alcohol ', ylabel='count'>

# %%
plt.title("Relation between Smoker and Overall Rating")
sns.countplot(df, x = "Smoker", hue = "Overall Rating")
# Out:
# <Axes: title={'center': 'Relation between Smoker and Overall Rating'}, xlabel='Smoker', ylabel='count'>

# %%
df.drop('Food Rating', axis = 1, inplace = True)
df.drop('Service Rating', axis = 1, inplace = True)

# %%
df
# Out:
#      Area code  Location  Gender  YOB  Marital Status  Activity  Budget  \
# 0           33         8       0   43               2         0       2
# 1           14         7       0   30               1         1       2
# 2           13         9       1   17               2         1       4
# 3           33         8       0    1               1         0       4
# 4           18         1       1   34               2         1       3
# ..         ...       ...     ...  ...             ...       ...     ...
# 195         48         7       0   22               2         0       3
# 196         45         9       0   37               1         1       3
# 197         38         7       0   43               2         0       4
# 198         19         7       1   39               1         1       2
# 199         27         8       1   42               1         1       3
#
#      Cuisines  Alcohol   Smoker  Overall Rating
# 0           5         0       0               7
# ...

# %%
df.corr()
# Out:
#                 Area code  Location    Gender       YOB  Marital Status  \
# Area code        1.000000 -0.000544  0.011161 -0.066946       -0.126050
# Location        -0.000544  1.000000 -0.216659 -0.028620       -0.143505
# Gender           0.011161 -0.216659  1.000000 -0.124711        0.020641
# YOB             -0.066946 -0.028620 -0.124711  1.000000        0.450594
# Marital Status  -0.126050 -0.143505  0.020641  0.450594        1.000000
# Activity         0.001110 -0.118050  0.149410  0.259236        0.105259
# Budget          -0.047057  0.221735 -0.117390 -0.064563        0.198079
# Cuisines         0.016338 -0.087561  0.119196  0.057098       -0.009439
# Alcohol         -0.008978 -0.111500  0.097924 -0.038778        0.018932
# Smoker          -0.019247  0.055018 -0.114812 -0.157008       -0.031668
# Overall Rating  -0.012156 -0.127653 -0.085445  0.055229       -0.047517
#
#                 Activity    Budget  Cuisines  Alcohol     Smoker  \
# ...

# %%
fig = plt.figure(figsize=(30,15))
sns.heatmap(df.corr(), cmap="YlGnBu", annot=True,  annot_kws={'size': 15})
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Correlation plot",fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Correlation plot')

# %%
plt.boxplot(df['Overall Rating'])
plt.show()

# %%
plt.boxplot(df['Gender'])
plt.show()

# %%
plt.boxplot(df)
plt.show()

# %% [markdown]
# I suggest **SVM**	model
